# %%
from VAREID.libraries.io.format_funcs import load_dataframe, join_dataframe, split_dataframe, save_json

# %%
FPATH = "/fs/ess/PAS2136/ggr_data/results/Plains_Grevys_Experiment_20_IA95_vp_limited/Plains_Grevys_Exp_20_IA80_vp_limited/frame_sampling/fs_annots.json"

t = 0.8

annots = load_dataframe(FPATH)
df = join_dataframe(annots)
print(len(df))
df = df[df['CA_score'] >= t]
print(len(df))
out_dict = split_dataframe(df)
save_json(out_dict, FPATH)
# Out:
# 690
# 682
