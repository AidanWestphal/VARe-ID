# %%
import json
import matplotlib.pyplot as plt
import os
from collections import defaultdict
from PIL import Image
from datetime import datetime
import numpy as np

# Path to your annotation file
# annots_paths = ["/fs/ess/PAS2136/ggr_data/results/GGR2020_subset_refactor_final/lca/lca_left_annots.json", 
#                 "/fs/ess/PAS2136/ggr_data/results/GGR2020_subset_refactor_final/lca/lca_right_annots.json",]
annots_paths = ["/fs/ess/PAS2136/ggr_data/results/Plains_Experiment_16_IA95_vp_limited/lca/lca_left_annots.json", ]
# annots_paths = ["/fs/ess/PAS2136/ggr_data/results/Grevys_Experiment_4/lca/lca_right_annots.json", ]
                # "/fs/ess/PAS2136/ggr_data/results/Grevys_Experiment_4/lca/lca_right_annots.json"]
# annots_paths = ["/fs/ess/PAS2136/ggr_data/results/Plains_Experiment_11/lca/lca_left_annots.json", 
#                 "/fs/ess/PAS2136/ggr_data/results/Plains_Experiment_11/lca/lca_right_annots.json"]
# Create output directory for figures
output_dir = "cluster_visualizations"
os.makedirs(output_dir, exist_ok=True)
print(f"Saving figures to: {output_dir}")

for annots_path in annots_paths:
    # Load the annotation data
    with open(annots_path, "r") as f:
        data = json.load(f)
    # Build a mapping from image_uuid to image_path
    uuid_to_path = {img["uuid"]: img["image_path"] for img in data["images"]}
    print(data)
    # Organize annotations by cluster and viewpoint
    clusters = defaultdict(lambda: defaultdict(list))
    for ann in data["annotations"]:
        cluster_id = ann.get("LCA_clustering_id", "unknown")
        viewpoint = ann.get("viewpoint", "unknown")
        image_uuid = ann["image_uuid"]
        image_path = uuid_to_path.get(image_uuid)
        bbox = ann.get("bbox")
        if image_path and bbox and os.path.exists(image_path):
            clusters[cluster_id][viewpoint].append((image_path, bbox, ann['uuid']))

    # Count total figures to generate
    total_figures = sum(len(viewpoints) for viewpoints in clusters.values())
    figure_count = 0

    # Visualization: save cropped images for each cluster and viewpoint, max 3 per row
    for cluster_id in sorted(clusters.keys(), key=lambda x: int(x) if x.isdigit() else x):
        print(f"\nProcessing Cluster {cluster_id}")
        for viewpoint in sorted(clusters[cluster_id].keys()):
            crops = clusters[cluster_id][viewpoint]
            n_crops = len(crops)
            if n_crops == 0:
                continue
            
            figure_count += 1
            print(f"  Generating figure {figure_count}/{total_figures}: Cluster {cluster_id} - Viewpoint {viewpoint}")
            
            n_cols = 3
            n_rows = (n_crops + n_cols - 1) // n_cols
            fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 4, n_rows * 4))
            
            # Ensure axes is always a list, even for single subplot
            if n_rows == 1 and n_cols == 1:
                axes = [axes]
            elif n_rows == 1 or n_cols == 1:
                axes = axes.flatten()
            else:
                axes = axes.flatten()
            
            fig.suptitle(f"Cluster {cluster_id} - Viewpoint: {viewpoint}", fontsize=16)
            
            for i, (img_path, bbox, annot_name) in enumerate(crops):
                ax = axes[i]
                try:
                    img = Image.open(img_path)
                    x, y, w, h = map(int, bbox)
                    crop = img.crop((x, y, x + w, y + h))
                    ax.imshow(crop)
                    ax.set_title(annot_name, fontsize=8)
                    ax.axis('off')
                except Exception as e:
                    ax.text(0.5, 0.5, f"Error: {e}", ha='center', va='center')
                    ax.axis('off')
            
            # Hide unused axes
            for j in range(n_crops, n_rows * n_cols):
                axes[j].axis('off')
            
            plt.tight_layout()
            
            # Save the figure
            filename = f"cluster_{cluster_id}_viewpoint_{viewpoint}.png"
            filepath = os.path.join(output_dir, filename)
            plt.savefig(filepath, dpi=150, bbox_inches='tight')
            plt.close(fig)  # Close to free memory
            print(f"    Saved: {filename}")

    print(f"\nCompleted! All {figure_count} figures saved to '{output_dir}' directory.")
# Out:
# Saving figures to: cluster_visualizations
# {'categories': [{'id': 0, 'species': 'plains zebra'}, {'id': 1, 'species': "grevy's zebra"}], 'images': [{'uuid': '410112a4-bce4-cd2a-3b98-12da69ff79bd', 'image_path': '/fs/ess/PAS2136/ggr_data/results/Plains_Experiment_16_IA95_vp_limited/images/DJI_0058_0296.jpg', 'video_path': '/fs/ess/PAS2136/ggr_data/video_data/Plains_Experiment_16/DJI_0058.MP4', 'frame_number': 296, 'timestamp': 1674060484.59604}, {'uuid': 'e0d8d35a-6bdf-505c-bf8a-73c18b4d4521', 'image_path': '/fs/ess/PAS2136/ggr_data/results/Plains_Experiment_16_IA95_vp_limited/images/DJI_0058_0308.jpg', 'video_path': '/fs/ess/PAS2136/ggr_data/video_data/Plains_Experiment_16/DJI_0058.MP4', 'frame_number': 308, 'timestamp': 1674060486.197566}, {'uuid': 'f04d3d87-2f10-c448-3b9d-b1a268d4404f', 'image_path': '/fs/ess/PAS2136/ggr_data/results/Plains_Experiment_16_IA95_vp_limited/images/DJI_0058_0662.jpg', 'video_path': '/fs/ess/PAS2136/ggr_data/video_data/Plains_Experiment_16/DJI_0058.MP4', 'frame_number': 662, 'timestamp': 1674060533.44231}, {'uuid': '4e5c5ec7-5e19-65a3-7bea-4fe3748010f5', 'image_path': '/fs/ess/PAS2136/ggr_data/results/Plains_Experiment_16_IA95_vp_limited/images/DJI_0056_0264.jpg', 'video_path': '/fs/ess/PAS2136/ggr_data/video_data/Plains_Experiment_16/DJI_0056.MP4', 'frame_number': 264, 'timestamp': 1674060092.358197}, {'uuid': 'f55d9b3b-cd59-d6a3-f5a9-22d024c5af19', 'image_path': '/fs/ess/PAS2136/ggr_data/results/Plains_Experiment_16_IA95_vp_limited/images/DJI_0056_0270.jpg', 'video_path': '/fs/ess/PAS2136/ggr_data/video_data/Plains_Experiment_16/DJI_0056.MP4', 'frame_number': 270, 'timestamp': 1674060093.15894}, {'uuid': '5cbfcd63-266e-1230-d190-7477ef698587', 'image_path': '/fs/ess/PAS2136/ggr_data/results/Plains_Experiment_16_IA95_vp_limited/images/DJI_0056_0280.jpg', 'video_path': '/fs/ess/PAS2136/ggr_data/video_data/Plains_Experiment_16/DJI_0056.MP4', 'frame_number': 280, 'timestamp': 1674060094.493528}, {'uuid': '21e5e126-bb7e-a3e3-77aa-4f01366b0bd7', 'image_path': '/fs/ess/PAS2136/ggr_data/results/Plains_Experiment_16_IA95_vp_limited/images/DJI_0056_0310.jpg', 'video_path': '/fs/ess/PAS2136/ggr_data/video_data/Plains_Experiment_16/DJI_0056.MP4', 'frame_number': 310, 'timestamp': 1674060098.497314}, {'uuid': '1400e41d-a988-79ae-d7fa-d335a7bb74ed', 'image_path': '/fs/ess/PAS2136/ggr_data/results/Plains_Experiment_16_IA95_vp_limited/images/DJI_0056_0321.jpg', 'video_path': '/fs/ess/PAS2136/ggr_data/video_data/Plains_Experiment_16/DJI_0056.MP4', 'frame_number': 321, 'timestamp': 1674060099.965376}, {'uuid': '2835979d-bc18-1ef0-5196-2340a1232c5a', 'image_path': '/fs/ess/PAS2136/ggr_data/results/Plains_Experiment_16_IA95_vp_limited/images/DJI_0056_0326.jpg', 'video_path': '/fs/ess/PAS2136/ggr_data/video_data/Plains_Experiment_16/DJI_0056.MP4', 'frame_number': 326, 'timestamp': 1674060100.63267}, {'uuid': '490d3dfd-1d59-da32-26d6-efdd7ecfff13', 'image_path': '/fs/ess/PAS2136/ggr_data/results/Plains_Experiment_16_IA95_vp_limited/images/DJI_0056_0455.jpg', 'video_path': '/fs/ess/PAS2136/ggr_data/video_data/Plains_Experiment_16/DJI_0056.MP4', 'frame_number': 455, 'timestamp': 1674060117.848955}, {'uuid': '3d92c36a-1496-65c4-7ac8-1e763e93b46e', 'image_path': '/fs/ess/PAS2136/ggr_data/results/Plains_Experiment_16_IA95_vp_limited/images/DJI_0056_0471.jpg', 'video_path': '/fs/ess/PAS2136/ggr_data/video_data/Plains_Experiment_16/DJI_0056.MP4', 'frame_number': 471, 'timestamp': 1674060119.984306}, {'uuid': '8b41d112-b194-cc0f-30b8-d2b96d54af1b', 'image_path': '/fs/ess/PAS2136/ggr_data/results/Plains_Experiment_16_IA95_vp_limited/images/DJI_0056_0474.jpg', 'video_path': '/fs/ess/PAS2136/ggr_data/video_data/Plains_Experiment_16/DJI_0056.MP4', 'frame_number': 474, 'timestamp': 1674060120.384683}, {'uuid': '792eb6aa-b205-7e4b-a89e-61a2febe6365', 'image_path': '/fs/ess/PAS2136/ggr_data/results/Plains_Experiment_16_IA95_vp_limited/images/DJI_0056_0482.jpg', 'video_path': '/fs/ess/PAS2136/ggr_data/video_data/Plains_Experiment_16/DJI_0056.MP4', 'frame_number': 482, 'times ...
#
# Processing Cluster 0
#   Generating figure 1/83: Cluster 0 - Viewpoint left
#     Saved: cluster_0_viewpoint_left.png
#
# Processing Cluster 1
#   Generating figure 2/83: Cluster 1 - Viewpoint left
#     Saved: cluster_1_viewpoint_left.png
#
# Processing Cluster 2
#   Generating figure 3/83: Cluster 2 - Viewpoint left
#     Saved: cluster_2_viewpoint_left.png
#
# Processing Cluster 3
#   Generating figure 4/83: Cluster 3 - Viewpoint left
#     Saved: cluster_3_viewpoint_left.png
#
# Processing Cluster 4
#   Generating figure 5/83: Cluster 4 - Viewpoint left
#     Saved: cluster_4_viewpoint_left.png
#
# Processing Cluster 5
#   Generating figure 6/83: Cluster 5 - Viewpoint left
#     Saved: cluster_5_viewpoint_left.png
#
# Processing Cluster 6
#   Generating figure 7/83: Cluster 6 - Viewpoint left
#     Saved: cluster_6_viewpoint_left.png
#
# Processing Cluster 7
#   Generating figure 8/83: Cluster 7 - Viewpoint left
#     Saved: cluster_7_viewpoint_left.png
#
# Processing Cluster 8
#   Generating figure 9/83: Cluster 8 - Viewpoint left
#     Saved: cluster_8_viewpoint_left.png
#
# Processing Cluster 9
#   Generating figure 10/83: Cluster 9 - Viewpoint left
#     Saved: cluster_9_viewpoint_left.png
#
# Processing Cluster 10
#   Generating figure 11/83: Cluster 10 - Viewpoint left
#     Saved: cluster_10_viewpoint_left.png
#
# Processing Cluster 11
#   Generating figure 12/83: Cluster 11 - Viewpoint left
#     Saved: cluster_11_viewpoint_left.png
#
# Processing Cluster 12
#   Generating figure 13/83: Cluster 12 - Viewpoint left
#     Saved: cluster_12_viewpoint_left.png
#
# Processing Cluster 13
#   Generating figure 14/83: Cluster 13 - Viewpoint left
#     Saved: cluster_13_viewpoint_left.png
#
# Processing Cluster 14
#   Generating figure 15/83: Cluster 14 - Viewpoint left
#     Saved: cluster_14_viewpoint_left.png
#
# Processing Cluster 15
#   Generating figure 16/83: Cluster 15 - Viewpoint left
#     Saved: cluster_15_viewpoint_left.png
#
# Processing Cluster 16
#   Generating figure 17/83: Cluster 16 - Viewpoint left
#     Saved: cluster_16_viewpoint_left.png
#
# Processing Cluster 17
#   Generating figure 18/83: Cluster 17 - Viewpoint left
#     Saved: cluster_17_viewpoint_left.png
#
# Processing Cluster 18
#   Generating figure 19/83: Cluster 18 - Viewpoint left
#     Saved: cluster_18_viewpoint_left.png
#
# Processing Cluster 19
#   Generating figure 20/83: Cluster 19 - Viewpoint left
#     Saved: cluster_19_viewpoint_left.png
#
# Processing Cluster 20
#   Generating figure 21/83: Cluster 20 - Viewpoint left
#     Saved: cluster_20_viewpoint_left.png
#
# Processing Cluster 21
#   Generating figure 22/83: Cluster 21 - Viewpoint left
#     Saved: cluster_21_viewpoint_left.png
#
# Processing Cluster 22
#   Generating figure 23/83: Cluster 22 - Viewpoint left
#     Saved: cluster_22_viewpoint_left.png
#
# Processing Cluster 23
#   Generating figure 24/83: Cluster 23 - Viewpoint left
#     Saved: cluster_23_viewpoint_left.png
#
# Processing Cluster 24
#   Generating figure 25/83: Cluster 24 - Viewpoint left
#     Saved: cluster_24_viewpoint_left.png
#
# Processing Cluster 25
#   Generating figure 26/83: Cluster 25 - Viewpoint left
#     Saved: cluster_25_viewpoint_left.png
#
# Processing Cluster 26
#   Generating figure 27/83: Cluster 26 - Viewpoint left
#     Saved: cluster_26_viewpoint_left.png
#
# Processing Cluster 27
#   Generating figure 28/83: Cluster 27 - Viewpoint left
#     Saved: cluster_27_viewpoint_left.png
#
# Processing Cluster 28
#   Generating figure 29/83: Cluster 28 - Viewpoint left
#     Saved: cluster_28_viewpoint_left.png
#
# Processing Cluster 29
#   Generating figure 30/83: Cluster 29 - Viewpoint left
#     Saved: cluster_29_viewpoint_left.png
#
# Processing Cluster 30
#   Generating figure 31/83: Cluster 30 - Viewpoint left
#     Saved: cluster_30_viewpoint_left.png
#
# Processing Cluster 31
#   Generating figure 32/83: Cluster 31 - Viewpoint left
#     Saved: cluster_31_viewpoint_left.png
#
# Processing Cluster 32
#   Generating figure 33/83: Cluster 32 - Viewpoint left
#     Saved: cluster_32_viewpoint_left.png
#
# Processing Cluster 33
#   Generating figure 34/83: Cluster 33 - Viewpoint left
#     Saved: cluster_33_viewpoint_left.png
#
# Processing Cluster 34
#   Generating figure 35/83: Cluster 34 - Viewpoint left
#     Saved: cluster_34_viewpoint_left.png
#
# Processing Cluster 35
#   Generating figure 36/83: Cluster 35 - Viewpoint left
#     Saved: cluster_35_viewpoint_left.png
#
# Processing Cluster 36
#   Generating figure 37/83: Cluster 36 - Viewpoint left
#     Saved: cluster_36_viewpoint_left.png
#
# Processing Cluster 37
#   Generating figure 38/83: Cluster 37 - Viewpoint left
#     Saved: cluster_37_viewpoint_left.png
#
# Processing Cluster 38
#   Generating figure 39/83: Cluster 38 - Viewpoint left
#     Saved: cluster_38_viewpoint_left.png
#
# Processing Cluster 39
#   Generating figure 40/83: Cluster 39 - Viewpoint left
#     Saved: cluster_39_viewpoint_left.png
#
# Processing Cluster 40
#   Generating figure 41/83: Cluster 40 - Viewpoint left
#     Saved: cluster_40_viewpoint_left.png
#
# Processing Cluster 41
#   Generating figure 42/83: Cluster 41 - Viewpoint left
#     Saved: cluster_41_viewpoint_left.png
#
# Processing Cluster 42
#   Generating figure 43/83: Cluster 42 - Viewpoint left
#     Saved: cluster_42_viewpoint_left.png
#
# Processing Cluster 43
#   Generating figure 44/83: Cluster 43 - Viewpoint left
#     Saved: cluster_43_viewpoint_left.png
#
# Processing Cluster 44
#   Generating figure 45/83: Cluster 44 - Viewpoint left
#     Saved: cluster_44_viewpoint_left.png
#
# Processing Cluster 45
#   Generating figure 46/83: Cluster 45 - Viewpoint left
#     Saved: cluster_45_viewpoint_left.png
#
# Processing Cluster 46
#   Generating figure 47/83: Cluster 46 - Viewpoint left
#     Saved: cluster_46_viewpoint_left.png
#
# Processing Cluster 47
#   Generating figure 48/83: Cluster 47 - Viewpoint left
#     Saved: cluster_47_viewpoint_left.png
#
# Processing Cluster 48
#   Generating figure 49/83: Cluster 48 - Viewpoint left
#     Saved: cluster_48_viewpoint_left.png
#
# Processing Cluster 49
#   Generating figure 50/83: Cluster 49 - Viewpoint left
#     Saved: cluster_49_viewpoint_left.png
#
# Processing Cluster 50
#   Generating figure 51/83: Cluster 50 - Viewpoint left
#     Saved: cluster_50_viewpoint_left.png
#
# Processing Cluster 51
#   Generating figure 52/83: Cluster 51 - Viewpoint left
#     Saved: cluster_51_viewpoint_left.png
#
# Processing Cluster 52
#   Generating figure 53/83: Cluster 52 - Viewpoint left
#     Saved: cluster_52_viewpoint_left.png
#
# Processing Cluster 53
#   Generating figure 54/83: Cluster 53 - Viewpoint left
#     Saved: cluster_53_viewpoint_left.png
#
# Processing Cluster 54
#   Generating figure 55/83: Cluster 54 - Viewpoint left
#     Saved: cluster_54_viewpoint_left.png
#
# Processing Cluster 55
#   Generating figure 56/83: Cluster 55 - Viewpoint left
#     Saved: cluster_55_viewpoint_left.png
#
# Processing Cluster 56
#   Generating figure 57/83: Cluster 56 - Viewpoint left
#     Saved: cluster_56_viewpoint_left.png
#
# Processing Cluster 57
#   Generating figure 58/83: Cluster 57 - Viewpoint left
#     Saved: cluster_57_viewpoint_left.png
#
# Processing Cluster 58
#   Generating figure 59/83: Cluster 58 - Viewpoint left
#     Saved: cluster_58_viewpoint_left.png
#
# Processing Cluster 59
#   Generating figure 60/83: Cluster 59 - Viewpoint left
#     Saved: cluster_59_viewpoint_left.png
#
# Processing Cluster 60
#   Generating figure 61/83: Cluster 60 - Viewpoint left
#     Saved: cluster_60_viewpoint_left.png
#
# Processing Cluster 61
#   Generating figure 62/83: Cluster 61 - Viewpoint left
#     Saved: cluster_61_viewpoint_left.png
#
# Processing Cluster 62
#   Generating figure 63/83: Cluster 62 - Viewpoint left
#     Saved: cluster_62_viewpoint_left.png
#
# Processing Cluster 63
#   Generating figure 64/83: Cluster 63 - Viewpoint left
#     Saved: cluster_63_viewpoint_left.png
#
# Processing Cluster 64
#   Generating figure 65/83: Cluster 64 - Viewpoint left
#     Saved: cluster_64_viewpoint_left.png
#
# Processing Cluster 65
#   Generating figure 66/83: Cluster 65 - Viewpoint left
#     Saved: cluster_65_viewpoint_left.png
#
# Processing Cluster 66
#   Generating figure 67/83: Cluster 66 - Viewpoint left
#     Saved: cluster_66_viewpoint_left.png
#
# Processing Cluster 67
#   Generating figure 68/83: Cluster 67 - Viewpoint left
#     Saved: cluster_67_viewpoint_left.png
#
# Processing Cluster 68
#   Generating figure 69/83: Cluster 68 - Viewpoint left
#     Saved: cluster_68_viewpoint_left.png
#
# Processing Cluster 69
#   Generating figure 70/83: Cluster 69 - Viewpoint left
#     Saved: cluster_69_viewpoint_left.png
#
# Processing Cluster 70
#   Generating figure 71/83: Cluster 70 - Viewpoint left
#     Saved: cluster_70_viewpoint_left.png
#
# Processing Cluster 71
#   Generating figure 72/83: Cluster 71 - Viewpoint left
#     Saved: cluster_71_viewpoint_left.png
#
# Processing Cluster 72
#   Generating figure 73/83: Cluster 72 - Viewpoint left
#     Saved: cluster_72_viewpoint_left.png
#
# Processing Cluster 73
#   Generating figure 74/83: Cluster 73 - Viewpoint left
#     Saved: cluster_73_viewpoint_left.png
#
# Processing Cluster 74
#   Generating figure 75/83: Cluster 74 - Viewpoint left
#     Saved: cluster_74_viewpoint_left.png
#
# Processing Cluster 75
#   Generating figure 76/83: Cluster 75 - Viewpoint left
#     Saved: cluster_75_viewpoint_left.png
#
# Processing Cluster 76
#   Generating figure 77/83: Cluster 76 - Viewpoint left
#     Saved: cluster_76_viewpoint_left.png
#
# Processing Cluster 77
#   Generating figure 78/83: Cluster 77 - Viewpoint left
#     Saved: cluster_77_viewpoint_left.png
#
# Processing Cluster 78
#   Generating figure 79/83: Cluster 78 - Viewpoint left
#     Saved: cluster_78_viewpoint_left.png
#
# Processing Cluster 79
#   Generating figure 80/83: Cluster 79 - Viewpoint left
#     Saved: cluster_79_viewpoint_left.png
#
# Processing Cluster 80
#   Generating figure 81/83: Cluster 80 - Viewpoint left
#     Saved: cluster_80_viewpoint_left.png
#
# Processing Cluster 81
#   Generating figure 82/83: Cluster 81 - Viewpoint left
#     Saved: cluster_81_viewpoint_left.png
#
# Processing Cluster 82
#   Generating figure 83/83: Cluster 82 - Viewpoint left
#     Saved: cluster_82_viewpoint_left.png
#
# Completed! All 83 figures saved to 'cluster_visualizations' directory.
